# %% [markdown]
# # Header1
# ## Header2
# ### Header3

# %% [markdown]
# 목록형
#  - 목록1
#  - 목록2
#  - 목록3
#
#  목록형2
#  * 목록4
#  * 목록5
#  + 목록6
#  - 목록7

# %% [markdown]
# 숫자목록
#
# 1. 하나
# 2. 둘
# 3. 셋
#
# 숙자2
#
# 1. 하나
# 1. 하나
# 1. 하나
# 1. 하나

# %% [markdown]
# 혼합
# - 리스트
#     - 목록1
#     - 목록2
#
# - 리스트2
#      1. 숫자1
#      1. 숫자2
#         - 목록3
#         + 목록4

# %% [markdown]
# 코드표시!
#
# ```python
# print("안녕하세요. 파이썬 프로그래밍 과정!!!")
# ```

# %% [markdown]
# 코드표시!
#
# ```
# print("안녕하세요. 파이썬 프로그래밍 과정!!!")
# ```

# %% [markdown]
# ### 이미지 링크!
#
# 마크다운 방식 : `![](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTmeNtFoiqjxmkBUFJCT8skEpPAn15XU2__Tw&usqp=CAU)`
#
# ![](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTmeNtFoiqjxmkBUFJCT8skEpPAn15XU2__Tw&usqp=CAU)

# %% [markdown]
# HTML방식
#
# <img src = "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTmeNtFoiqjxmkBUFJCT8skEpPAn15XU2__Tw&usqp=CAU">

# %% [markdown]
# HTML방식 - 이미지 크기 조정!
#
# <img src = "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTmeNtFoiqjxmkBUFJCT8skEpPAn15XU2__Tw&usqp=CAU"
#      width = 150>

# %% [markdown]
# raw 방식 :
#
# ![image.png](attachment:image.png)

# %%
print("안녕하세요. 파이썬 프로그래밍 과정!!!")
msg = "안녕하세요. 파이썬 프로그래밍 과정!!!"
print(msg)
# Out:
# 안녕하세요. 파이썬 프로그래밍 과정!!!
# 안녕하세요. 파이썬 프로그래밍 과정!!!

# %%
print(10000**10)
# Out:
# 10000000000000000000000000000000000000000
